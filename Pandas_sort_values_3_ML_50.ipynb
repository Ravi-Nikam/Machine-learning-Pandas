# %%
# pandas sort multiple values
import pandas as pd
nba=pd.read_csv("nba.csv")
nba
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.sort_values(["Team","Number"])
# Out:
#                  Name                Team  Number Position  Age  Height  \
# 323       Jeff Teague       Atlanta Hawks       0       PG   27   2-Jun
# 315      Paul Millsap       Atlanta Hawks       4       PF   31   8-Jun
# 310  Tim Hardaway Jr.       Atlanta Hawks      10       SG   24   6-Jun
# 321    Tiago Splitter       Atlanta Hawks      11        C   31  11-Jun
# 311      Kirk Hinrich       Atlanta Hawks      12       SG   35   4-Jun
# ..                ...                 ...     ...      ...  ...     ...
# 380    Garrett Temple  Washington Wizards      17       SG   30   6-Jun
# 374        JJ Hickson  Washington Wizards      21        C   27   9-Jun
# 378   Otto Porter Jr.  Washington Wizards      22       SF   23   8-Jun
# 375      Nene Hilario  Washington Wizards      42        C   33  11-Jun
# 372       Drew Gooden  Washington Wizards      90       PF   34  10-Jun
#
#      Weight               College      Salary
# 323     186           Wake Forest   8000000.0
# ...

# %%
# sort multiple values with ascending and decending order
nba.sort_values(["Team","Number"],ascending=[True,False])
# Out:
#                 Name                Team  Number Position  Age  Height  \
# 313   Kris Humphries       Atlanta Hawks      43       PF   31   9-Jun
# 319       Mike Scott       Atlanta Hawks      32       PF   27   8-Jun
# 316     Mike Muscala       Atlanta Hawks      31       PF   24  11-Jun
# 314      Kyle Korver       Atlanta Hawks      26       SG   35   7-Jun
# 320  Thabo Sefolosha       Atlanta Hawks      25       SF   32   7-Jun
# ..               ...                 ...     ...      ...  ...     ...
# 368    Alan Anderson  Washington Wizards       6       SG   33   6-Jun
# 376  Markieff Morris  Washington Wizards       5       PF   26  10-Jun
# 369     Bradley Beal  Washington Wizards       3       SG   22   5-Jun
# 382        John Wall  Washington Wizards       2       PG   25   4-Jun
# 370     Jared Dudley  Washington Wizards       1       SF   30   7-Jun
#
#      Weight         College      Salary
# 313     235       Minnesota   1000000.0
# ...
