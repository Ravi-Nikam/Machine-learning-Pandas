# %%
# logical operator AND and OR


import pandas as pd
df=pd.read_csv("employee.csv",parse_dates=['Start Date','Last Login Time']).dropna(how="all")
df["Team"].fillna("No Team",inplace=True)
df["Salary"].fillna(0,inplace=True)
df["Senior Management"] = df["Senior Management"].astype(bool)
df["Gender"] = df["Gender"].astype("category")
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-04-25 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-04-25 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-04-25 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-04-25 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-04-25 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-04-25 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-04-25 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-04-25 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-04-25 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-04-25 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
# and operator
mask1 = df["Gender"] == "Male"
mask2 = df["Team"] == "No Team"
mask3 = df["Salary"] > 120000
df[mask1 & mask2 & mask3]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 23         NaN   Male 2012-06-14 2020-04-25 16:19:00  125792    5.042
# 32         NaN   Male 1998-08-21 2020-04-25 14:27:00  122340    6.417
# 199   Jonathan   Male 2009-07-17 2020-04-25 08:15:00  130581   16.736
# 290     Jeremy   Male 1988-06-14 2020-04-25 18:20:00  129460   13.657
# 647     Donald   Male 1988-04-06 2020-04-25 10:00:00  122920    5.320
# 706       Todd   Male 1993-07-04 2020-04-25 18:53:00  128175   18.473
# 850    Charles   Male 1997-09-03 2020-04-25 10:04:00  148291    6.002
# 851      Bobby   Male 1996-08-19 2020-04-25 01:16:00  147842   16.158
# 912        Joe   Male 1998-12-08 2020-04-25 10:28:00  126120    1.020
#
#      Senior Management     Team
# 23                True  No Team
# 32                True  No Team
# 199               True  No Team
# 290               True  No Team
# 647              False  No Team
# 706               True  No Team
# 850              False  No Team
# ...

# %%
# or and not
mask1 = df["Bonus %"] < 1.5
mask2 = df["Team"] == "No Team"
mask3 = df["Start Date"] < "1996-03-31"
df[mask1 | mask2 & mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24 2020-04-25 16:47:00  101004    1.389
# 10      Louise  Female 1980-08-12 2020-04-25 09:01:00   63241   15.132
# 15     Lillian  Female 2016-06-05 2020-04-25 06:09:00   59414    1.256
# 58     Theresa  Female 2010-04-11 2020-04-25 07:18:00   72670    1.481
# 77     Charles    Male 2004-09-14 2020-04-25 20:13:00  107391    1.260
# 139        NaN  Female 1990-10-03 2020-04-25 01:08:00  132373   10.527
# 175     Willie    Male 1998-02-17 2020-04-25 20:20:00  146651    1.451
# 189   Clarence    Male 1998-05-02 2020-04-25 03:16:00   85700    1.215
# 217    Douglas    Male 1999-09-03 2020-04-25 16:00:00   83341    1.015
# 273   Nicholas    Male 1994-04-12 2020-04-25 20:21:00   74669    1.113
# 279       Ruby  Female 2000-11-08 2020-04-25 19:35:00  105946    1.139
# 290     Jeremy    Male 1988-06-14 2020-04-25 18:20:00  129460   13.657
# ...
