# %%
# Read csv file


import pandas as pd

s=pd.read_csv('test.csv',squeeze=True,usecols=['E Mail'])
s
# Out:
# 0                shawna.buck@gmail.com
# 1          nathaniel.burke@walmart.com
# 2           elisabeth.foster@gmail.com
# 3           briana.lancaster@yahoo.com
# 4             estella.potter@gmail.com
#                     ...
# 995                bonnie.baker@bp.com
# 996            luke.turner@charter.net
# 997             eva.holman@hotmail.com
# 998    maritza.christian@microsoft.com
# 999         phyllis.dudley@yahoo.co.in
# Name: E Mail, Length: 1000, dtype: object

# %%
s.ndim
# Out:
# 1

# %%
s.size
# Out:
# 1000

# %%
s.head(10)
# Out:
# 0          shawna.buck@gmail.com
# 1    nathaniel.burke@walmart.com
# 2     elisabeth.foster@gmail.com
# 3     briana.lancaster@yahoo.com
# 4       estella.potter@gmail.com
# 5       lamont.woods@hotmail.com
# 6      melinda.lopez@hotmail.com
# 7         shanna.silva@gmail.com
# 8      jasmine.freeman@gmail.com
# 9          madge.sargent@aol.com
# Name: E Mail, dtype: object

# %%
s.tail()
# Out:
# 995                bonnie.baker@bp.com
# 996            luke.turner@charter.net
# 997             eva.holman@hotmail.com
# 998    maritza.christian@microsoft.com
# 999         phyllis.dudley@yahoo.co.in
# Name: E Mail, dtype: object

# %%
# show range of index
s.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# show all values of dataset
s.values
# Out:
# array(['shawna.buck@gmail.com', 'nathaniel.burke@walmart.com',
#        'elisabeth.foster@gmail.com', 'briana.lancaster@yahoo.com',
#        'estella.potter@gmail.com', 'lamont.woods@hotmail.com',
#        'melinda.lopez@hotmail.com', 'shanna.silva@gmail.com',
#        'jasmine.freeman@gmail.com', 'madge.sargent@aol.com',
#        'bethany.cline@yahoo.ca', 'reid.randolph@gmail.com',
#        'antoine.wiley@verizon.net', 'mathew.hodge@hotmail.com',
#        'bernardo.austin@hotmail.com', 'cole.jensen@aol.com',
#        'tonia.burns@gmail.com', 'tod.holcomb@outlook.com',
#        'yesenia.guerrero@btinternet.com', 'carey.ferrell@yahoo.com',
#        'aileen.blanchard@gmail.com', 'marta.cervantes@gmail.com',
#        'arthur.holloway@aol.com', 'tara.forbes@gmail.com',
#        'josef.griffin@yahoo.com', 'keri.slater@apple.com',
#        'desmond.wynn@hotmail.com', 'adrienne.puckett@verizon.net',
#        'beatriz.knowles@gmail.com', 'jermaine.sykes@apple.com',
# ...

# %%
# give shape of dataset means Row and column thare are 1000 row but 0 column so op is (1000,)
s.shape
# Out:
# (1000,)

# %%
# getting column name
s.name
# Out:
# 'email'

# %%
# change the temporary name of columns
s.name = 'email'
s.name
# Out:
# 'email'

# %%
# count  total no of row 
s.count
# Out:
# <bound method Series.count of 0                shawna.buck@gmail.com
# 1          nathaniel.burke@walmart.com
# 2           elisabeth.foster@gmail.com
# 3           briana.lancaster@yahoo.com
# 4             estella.potter@gmail.com
#                     ...
# 995                bonnie.baker@bp.com
# 996            luke.turner@charter.net
# 997             eva.holman@hotmail.com
# 998    maritza.christian@microsoft.com
# 999         phyllis.dudley@yahoo.co.in
# Name: email, Length: 1000, dtype: object>

# %%
# find all row value are unique or not
s.is_unique
# Out:
# True
